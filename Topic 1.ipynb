# %% [markdown]
# ### Topic 1 : Introduction to Python
# Installing Python Packages, Importing Data, Basic Checks, Datatypes, Exporting Data

# %% [markdown]
# ### 1. Installation of Packages

# %%
# Installing from Jupyter Notebook
import sys
# !{sys.executable} -m pip install pandas

# %%
# Installing from Anaconda prompt
#pip install <package-name>
#conda install <package-name>

# %%
# Importing Packages
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Importing Data in Python
# Most of the time, you’ll use either NumPy or pandas to import your data

# %%
# Importing Packages
import pandas as pd

# %% [markdown]
# #### 2.1 Importing a text file

# %%
# Importing a text file
df1 = pd.read_csv(r'C:\Users\sjeeva2\Desktop\Sample_Employee_Data.txt', sep='\t')
print (df1)
# Out:
#     Emp ID Gender Date of Birth  Age in Yrs.  Weight in Kgs. Date of Joining  \
# 0   677509      F     3/29/1981        36.36              60      11/24/2003
# 1   940761      F     7/31/1970        47.02              60       7/27/2008
# 2   428945      M     6/16/1963        54.15              68        8/3/2016
# 3   408351      F     12/4/1977        39.67              51       4/16/1999
# 4   193819      M     4/17/1977        40.31              58       7/25/2013
# 5   499687      M     9/27/1982        34.86              58       7/22/2005
# 6   539712      F     6/13/1995        22.14              50       9/14/2016
# 7   380086      F     6/30/1958        59.12              40       1/28/1983
# 8   477616      F      6/9/1959        58.18              42       4/27/1994
# 9   162402      F    11/13/1987        29.73              60       2/17/2014
# 10  231469      M      2/5/1975        42.50              80       4/14/2009
# ...

# %% [markdown]
# #### 2.2 Importing a csv file

# %%
#Importing a csv file
df2 = pd.read_csv(r'C:\Users\sjeeva2\Desktop\Retail_Agg_Data.csv')
print (df2)
# Out:
#     Customer_ID  No_Of_Times_Visited  Total_Amount_Spent  \
# 0      AA-10315                    5           5563.5600
# 1      AA-10375                    9           1056.3900
# 2      AA-10480                    4           1790.5120
# 3      AA-10645                    6           5086.9350
# 4      AB-10015                    3            886.1560
# 5      AB-10060                    8           7755.6200
# 6      AB-10105                   10          14473.5710
# 7      AB-10150                    5            966.7100
# 8      AB-10165                    8           1113.8380
# 9      AB-10255                    9            914.5320
# 10     AB-10600                    4           1515.8620
# 11     AC-10420                    3            925.8000
# 12     AC-10450                    7           5527.8460
# 13     AC-10615                    5           2537.6860
# 14     AC-10660                    5            657.3160
# ...

# %%
df2 = pd.read_csv(r'C:\Users\sjeeva2\Desktop\Retail_Agg_Data.csv',nrows=5)
print (df2)
# Out:
#   Customer_ID  No_Of_Times_Visited  Total_Amount_Spent  Days_Since_Last_Visit
# 0    AA-10315                    5            5563.560                    186
# 1    AA-10375                    9            1056.390                     21
# 2    AA-10480                    4            1790.512                    261
# 3    AA-10645                    6            5086.935                     57
# 4    AB-10015                    3             886.156                    417

# %%
df2 = pd.read_csv(r'C:\Users\sjeeva2\Desktop\Retail_Agg_Data.csv',nrows=5,header=None)
print (df2)
# Out:
#              0                    1                   2                      3
# 0  Customer_ID  No_Of_Times_Visited  Total_Amount_Spent  Days_Since_Last_Visit
# 1     AA-10315                    5             5563.56                    186
# 2     AA-10375                    9             1056.39                     21
# 3     AA-10480                    4            1790.512                    261
# 4     AA-10645                    6            5086.935                     57

# %% [markdown]
# #### 2.3 Importing an excel file

# %%
#Importing a excel file
df3 = pd.read_excel(r'C:\Users\sjeeva2\Desktop\Retail_Sample_Data.xlsx')
print (df3)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10    CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 11    CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %%
df3 = pd.read_excel(r'C:\Users\sjeeva2\Desktop\Retail_Sample_Data.xlsx', sheet_name='Transaction_data')
print (df3)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10    CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 11    CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %% [markdown]
# #### 2.4 Importing a sas file

# %%
#Importing a sas file
df4 = pd.read_sas(r'C:\Users\sjeeva2\Desktop\iris.sas7bdat',encoding="latin-1")
print (df4)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0             5.1          3.5           1.4          0.2  setosa
# 1             4.9          3.0           1.4          0.2  setosa
# 2             4.7          3.2           1.3          0.2  setosa
# 3             4.6          3.1           1.5          0.2  setosa
# 4             5.0          3.6           1.4          0.2  setosa
# 5             5.4          3.9           1.7          0.4  setosa
# 6             4.6          3.4           1.4          0.3  setosa
# 7             5.0          3.4           1.5          0.2  setosa
# 8             4.4          2.9           1.4          0.2  setosa
# 9             4.9          3.1           1.5          0.1  setosa
# 10            5.4          3.7           1.5          0.2  setosa
# 11            4.8          3.4           1.6          0.2  setosa
# 12            4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# ### 3. Basic Checks - Exploring the Data

# %%
# The head() function is used to get the first n rows
df3.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Region         Category Sub-Category     Sales  \
# 0      Claire Gute   Consumer  South        Furniture    Bookcases  261.9600
# 1      Claire Gute   Consumer  South        Furniture       Chairs  731.9400
# 2  Darrin Van Huff  Corporate   West  Office Supplies       Labels   14.6200
# 3   Sean O'Donnell   Consumer  South        Furniture       Tables  957.5775
# 4   Sean O'Donnell   Consumer  South  Office Supplies      Storage   22.3680
#
#    Quantity  Discount    Profit  Satisfaction Score
# ...

# %%
df3.head(10)
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment Region         Category Sub-Category     Sales  \
# 0      Claire Gute   Consumer  South        Furniture    Bookcases  261.9600
# ...

# %%
# The tail() function is used to get the last n rows
df3.tail()
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name   Segment Region         Category Sub-Category  \
# 9989  Tom Boeckenhauer  Consumer  South        Furniture  Furnishings
# 9990       Dave Brooks  Consumer   West        Furniture  Furnishings
# 9991       Dave Brooks  Consumer   West       Technology       Phones
# 9992       Dave Brooks  Consumer   West  Office Supplies        Paper
# 9993      Chris Cortes  Consumer   West  Office Supplies   Appliances
#
#         Sales  Quantity  Discount   Profit  Satisfaction Score
# ...

# %%
# To get the No of rows and columns
df3.shape
# Out:
# (9994, 15)

# %%
# Information on the dataframe
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 15 columns):
# Order ID              9994 non-null object
# Order Date            9994 non-null datetime64[ns]
# Ship Date             9994 non-null datetime64[ns]
# Ship Mode             9994 non-null object
# Customer ID           9994 non-null object
# Customer Name         9994 non-null object
# Segment               9994 non-null object
# Region                9994 non-null object
# Category              9994 non-null object
# Sub-Category          9994 non-null object
# Sales                 9994 non-null float64
# Quantity              9994 non-null int64
# Discount              9994 non-null float64
# Profit                9994 non-null float64
# Satisfaction Score    9994 non-null int64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
# Desribes the Index
df3.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
# Returns the dataframe columns
df3.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Region', 'Category', 'Sub-Category',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Satisfaction Score'],
#       dtype='object')

# %%
# Returns Number of non-NA values
df3.count()
# Out:
# Order ID              9994
# Order Date            9994
# Ship Date             9994
# Ship Mode             9994
# Customer ID           9994
# Customer Name         9994
# Segment               9994
# Region                9994
# Category              9994
# Sub-Category          9994
# Sales                 9994
# Quantity              9994
# Discount              9994
# Profit                9994
# Satisfaction Score    9994
# dtype: int64

# %%
# Returns Summary statistics for Numerical columns
df3.describe()
# Out:
#               Sales     Quantity     Discount       Profit  Satisfaction Score
# count   9994.000000  9994.000000  9994.000000  9994.000000         9994.000000
# mean     229.858001     3.789574     0.156203    28.656896            3.003902
# std      623.245101     2.225110     0.206452   234.260108            1.410701
# min        0.444000     1.000000     0.000000 -6599.978000            1.000000
# 25%       17.280000     2.000000     0.000000     1.728750            2.000000
# 50%       54.490000     3.000000     0.200000     8.666500            3.000000
# 75%      209.940000     5.000000     0.200000    29.364000            4.000000
# max    22638.480000    14.000000     0.800000  8399.976000            5.000000

# %%
# Count unique values in each column of the dataframe
UniqueValues = df3.nunique()
print(UniqueValues)
# Out:
# Order ID              5009
# Order Date            1237
# Ship Date             1334
# Ship Mode                4
# Customer ID            793
# Customer Name          793
# Segment                  3
# Region                   4
# Category                 3
# Sub-Category            17
# Sales                 5825
# Quantity                14
# Discount                12
# Profit                7287
# Satisfaction Score       5
# dtype: int64

# %%
# Unique values of a categorical column
df3['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# ### 4. Datatypes
# Checking Datatypes in data frame, Converting Datatypes

# %%
# Check the Data Type in Pandas DataFrame
df3.dtypes
# Out:
# Order ID                      object
# Order Date            datetime64[ns]
# Ship Date             datetime64[ns]
# Ship Mode                     object
# Customer ID                   object
# Customer Name                 object
# Segment                       object
# Region                        object
# Category                      object
# Sub-Category                  object
# Sales                        float64
# Quantity                       int64
# Discount                     float64
# Profit                       float64
# Satisfaction Score             int64
# dtype: object

# %%
# Check the data type of a particular column
df3['Profit'].dtypes
# Out:
# dtype('float64')

# %%
# Convert Integers to Strings
df3['Satisfaction Score'] = df3['Satisfaction Score'].astype(str)

# %%
df3['Satisfaction Score'].dtypes
# Out:
# dtype('O')

# %%
# Convert strings to Integers
df3['Satisfaction Score'] = df3['Satisfaction Score'].astype(int)

# %%
df3['Satisfaction Score'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# ### 5. Exporting Data

# %% [markdown]
# #### 5.1 Exporting to csv file

# %%
# Exporting pandas dataframe to csv
df3.to_csv('MyDataFrame.csv',index=False)

# %% [markdown]
# #### 5.2 Exporting to excel file

# %%
# Exporting pandas dataframe to excel
df3.to_excel('MyDataFrame.xlsx',index=False, sheet_name='Sheet1')

# %% [markdown]
# ## Thankyou!
